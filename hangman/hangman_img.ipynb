# %%
def hang0 ():
    print("")
    return

def hang1 ():
    print("                ")
    print("                ")
    print("                ")
    print("                ")
    print("                ")
    print("                ")
    print("  _____________ ")
    print(" /            /|")
    print("/____________/ /")
    print("|____________|/ ") 
    return

def hang2 ():
    print("                ")
    print("                ")
    print("    |           ")
    print("    |           ")
    print("    |           ")
    print("    |           ")
    print("  __|__________ ")
    print(" /  |         /|")
    print("/____________/ /")
    print("|____________|/ ") 
    return

def hang3 ():
    print("                ")
    print("    ________    ")
    print("    |           ")
    print("    |           ")
    print("    |           ")
    print("    |           ")
    print("  __|__________ ")
    print(" /  |         /|")
    print("/____________/ /")
    print("|____________|/ ") 
    return

def hang4 ():
    print("                ")
    print("    ________    ")
    print("    |      |    ")
    print("    |           ")
    print("    |           ")
    print("    |           ")
    print("  __|__________ ")
    print(" /  |         /|")
    print("/____________/ /")
    print("|____________|/ ") 
    return

def hang5 ():
    print("                ")
    print("    ________    ")
    print("    |      |    ")
    print("    |      @    ")
    print("    |           ")
    print("    |           ")
    print("  __|__________ ")
    print(" /  |         /|")
    print("/____________/ /")
    print("|____________|/ ") 
    return

def hang6 ():
    print("                ")
    print("    ________    ")
    print("    |      |    ")
    print("    |      @    ")
    print("    |      |    ")
    print("    |           ")
    print("  __|__________ ")
    print(" /  |         /|")
    print("/____________/ /")
    print("|____________|/ ") 
    return

def hang7 ():
    print("                ")
    print("    ________    ")
    print("    |      |    ")
    print("    |      @    ")
    print("    |     /|    ")
    print("    |           ")
    print("  __|__________ ")
    print(" /  |         /|")
    print("/____________/ /")
    print("|____________|/ ") 
    return

def hang8 ():
    print("                ")
    print("    ________    ")
    print("    |      |    ")
    print("    |      @    ")
    print("    |     /|\   ")
    print("    |           ")
    print("  __|__________ ")
    print(" /  |         /|")
    print("/____________/ /")
    print("|____________|/ ") 
    return

def hang9 ():
    print("                ")
    print("    ________    ")
    print("    |      |    ")
    print("    |      @    ")
    print("    |     /|\   ")
    print("    |     /     ")
    print("  __|__________ ")
    print(" /  |         /|")
    print("/____________/ /")
    print("|____________|/ ") 
    return

def hang10 ():
    print("                ")
    print("    ________    ")
    print("    |      |    ")
    print("    |      @    ")
    print("    |     /|\   ")
    print("    |     / \   ")
    print("  __|__________ ")
    print(" /  |         /|")
    print("/____________/ /")
    print("|____________|/ ") 
    return

import time

img_dict = {
    '0' : hang0,
    '1' : hang1,
    '2' : hang2,
    '3' : hang3,
    '4' : hang4,
    '5' : hang5,
    '6' : hang6,
    '7' : hang7,
    '8' : hang8,
    '9' : hang9,
    '10' : hang10
}

for i in range (11):
    func = img_dict[str(i)]
    func()
# Out:
#
#
#
#
#
#
#   _____________
#  /            /|
# /____________/ /
# |____________|/
#
#
#     |
#     |
#     |
#     |
#   __|__________
#  /  |         /|
# /____________/ /
# |____________|/
#
#     ________
#     |
#     |
#     |
#     |
#   __|__________
#  /  |         /|
# /____________/ /
# |____________|/
#
#     ________
#     |      |
#     |
#     |
#     |
#   __|__________
#  /  |         /|
# /____________/ /
# |____________|/
#
#     ________
#     |      |
#     |      @
#     |
#     |
#   __|__________
#  /  |         /|
# /____________/ /
# |____________|/
#
#     ________
#     |      |
#     |      @
#     |      |
#     |
#   __|__________
#  /  |         /|
# /____________/ /
# |____________|/
#
#     ________
#     |      |
#     |      @
#     |     /|
#     |
#   __|__________
#  /  |         /|
# /____________/ /
# |____________|/
#
#     ________
#     |      |
#     |      @
#     |     /|\
#     |
#   __|__________
#  /  |         /|
# ...

# %%
def hang (i):
    if i == 0:
        print("")
    
    elif i == 1:
        print("                ")
        print("                ")
        print("                ")
        print("                ")
        print("                ")
        print("                ")
        print("  _____________ ")
        print(" /            /|")
        print("/____________/ /")
        print("|____________|/ ") 
    
    elif i == 2:
        print("                ")
        print("                ")
        print("    |           ")
        print("    |           ")
        print("    |           ")
        print("    |           ")
        print("  __|__________ ")
        print(" /  |         /|")
        print("/____________/ /")
        print("|____________|/ ") 
    
    elif i == 3:
        print("                ")
        print("    ________    ")
        print("    |           ")
        print("    |           ")
        print("    |           ")
        print("    |           ")
        print("  __|__________ ")
        print(" /  |         /|")
        print("/____________/ /")
        print("|____________|/ ") 
    
    elif i == 4:
        print("                ")
        print("    ________    ")
        print("    |      |    ")
        print("    |           ")
        print("    |           ")
        print("    |           ")
        print("  __|__________ ")
        print(" /  |         /|")
        print("/____________/ /")
        print("|____________|/ ") 
        
    elif i == 5:
        print("                ")
        print("    ________    ")
        print("    |      |    ")
        print("    |      @    ")
        print("    |           ")
        print("    |           ")
        print("  __|__________ ")
        print(" /  |         /|")
        print("/____________/ /")
        print("|____________|/ ") 
        
    elif i == 6:
        print("                ")
        print("    ________    ")
        print("    |      |    ")
        print("    |      @    ")
        print("    |      |    ")
        print("    |           ")
        print("  __|__________ ")
        print(" /  |         /|")
        print("/____________/ /")
        print("|____________|/ ") 
    
    elif i == 7:
        print("                ")
        print("    ________    ")
        print("    |      |    ")
        print("    |      @    ")
        print("    |     /|    ")
        print("    |           ")
        print("  __|__________ ")
        print(" /  |         /|")
        print("/____________/ /")
        print("|____________|/ ") 
    
    elif i == 8:
        print("                ")
        print("    ________    ")
        print("    |      |    ")
        print("    |      @    ")
        print("    |     /|\   ")
        print("    |           ")
        print("  __|__________ ")
        print(" /  |         /|")
        print("/____________/ /")
        print("|____________|/ ") 
    
    elif i == 9:
        print("                ")
        print("    ________    ")
        print("    |      |    ")
        print("    |      @    ")
        print("    |     /|\   ")
        print("    |     /     ")
        print("  __|__________ ")
        print(" /  |         /|")
        print("/____________/ /")
        print("|____________|/ ") 
        
    elif i == 10:
        print("                ")
        print("    ________    ")
        print("    |      |    ")
        print("    |      @    ")
        print("    |     /|\   ")
        print("    |     / \   ")
        print("  __|__________ ")
        print(" /  |         /|")
        print("/____________/ /")
        print("|____________|/ ") 
    
    return

for i in range(12):
    hang(i)
# Out:
#
#
#
#
#
#
#   _____________
#  /            /|
# /____________/ /
# |____________|/
#
#
#     |
#     |
#     |
#     |
#   __|__________
#  /  |         /|
# /____________/ /
# |____________|/
#
#     ________
#     |
#     |
#     |
#     |
#   __|__________
#  /  |         /|
# /____________/ /
# |____________|/
#
#     ________
#     |      |
#     |
#     |
#     |
#   __|__________
#  /  |         /|
# /____________/ /
# |____________|/
#
#     ________
#     |      |
#     |      @
#     |
#     |
#   __|__________
#  /  |         /|
# /____________/ /
# |____________|/
#
#     ________
#     |      |
#     |      @
#     |      |
#     |
#   __|__________
#  /  |         /|
# /____________/ /
# |____________|/
#
#     ________
#     |      |
#     |      @
#     |     /|
#     |
#   __|__________
#  /  |         /|
# /____________/ /
# |____________|/
#
#     ________
#     |      |
#     |      @
#     |     /|\
#     |
#   __|__________
#  /  |         /|
# ...
