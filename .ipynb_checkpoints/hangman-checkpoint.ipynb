# %%
#!/bin/python3.8

# This script is a game of Hangman, written in Python
from random_word import RandomWords
import string
letters = string.ascii_lowercase + string.ascii_uppercase
r = RandomWords()

def func_wordGet():
    while True:
        word = r.get_random_word()
        for char in word:
            if char.isalpha() == False:
                Letters = False
            else:
                Letters = True
        if Letters == True:
            word = word.lower()
            break
    return (word)  

Guesses = ""
def func_guess():
    global Guesses
    while True:
        goodGuess = True
        guess = input()
        if len(guess) == 1:
            for char in guess:
                if char.isalpha() == False or char == " ":
                    print("Letters only please.")
                    goodGuess = False
                if char in Guesses:
                    print("You have already that letter, try again.")
                    goodGuess = False
        else:
            print("One letter at a time please.")
            goodGuess = False
        guess = guess.lower()
        if goodGuess != False:
            Guesses = Guesses + guess + ", "
            break
    return (guess)

def hang (i):
    if i == 0:
        print("")
    
    elif i == 1:
        print("                ")
        print("                ")
        print("                ")
        print("                ")
        print("                ")
        print("                ")
        print("  _____________ ")
        print(" /            /|")
        print("/____________/ /")
        print("|____________|/ ") 
    
    elif i == 2:
        print("                ")
        print("                ")
        print("    |           ")
        print("    |           ")
        print("    |           ")
        print("    |           ")
        print("  __|__________ ")
        print(" /  |         /|")
        print("/____________/ /")
        print("|____________|/ ") 
    
    elif i == 3:
        print("                ")
        print("    ________    ")
        print("    |           ")
        print("    |           ")
        print("    |           ")
        print("    |           ")
        print("  __|__________ ")
        print(" /  |         /|")
        print("/____________/ /")
        print("|____________|/ ") 
    
    elif i == 4:
        print("                ")
        print("    ________    ")
        print("    |      |    ")
        print("    |           ")
        print("    |           ")
        print("    |           ")
        print("  __|__________ ")
        print(" /  |         /|")
        print("/____________/ /")
        print("|____________|/ ") 
        
    elif i == 5:
        print("                ")
        print("    ________    ")
        print("    |      |    ")
        print("    |      @    ")
        print("    |           ")
        print("    |           ")
        print("  __|__________ ")
        print(" /  |         /|")
        print("/____________/ /")
        print("|____________|/ ") 
        
    elif i == 6:
        print("                ")
        print("    ________    ")
        print("    |      |    ")
        print("    |      @    ")
        print("    |      |    ")
        print("    |           ")
        print("  __|__________ ")
        print(" /  |         /|")
        print("/____________/ /")
        print("|____________|/ ") 
    
    elif i == 7:
        print("                ")
        print("    ________    ")
        print("    |      |    ")
        print("    |      @    ")
        print("    |     /|    ")
        print("    |           ")
        print("  __|__________ ")
        print(" /  |         /|")
        print("/____________/ /")
        print("|____________|/ ") 
    
    elif i == 8:
        print("                ")
        print("    ________    ")
        print("    |      |    ")
        print("    |      @    ")
        print("    |     /|\   ")
        print("    |           ")
        print("  __|__________ ")
        print(" /  |         /|")
        print("/____________/ /")
        print("|____________|/ ") 
    
    elif i == 9:
        print("                ")
        print("    ________    ")
        print("    |      |    ")
        print("    |      @    ")
        print("    |     /|\   ")
        print("    |     /     ")
        print("  __|__________ ")
        print(" /  |         /|")
        print("/____________/ /")
        print("|____________|/ ") 
        
    elif i == 10:
        print("                ")
        print("    ________    ")
        print("    |      |    ")
        print("    |      @    ")
        print("    |     /|\   ")
        print("    |     / \   ")
        print("  __|__________ ")
        print(" /  |         /|")
        print("/____________/ /")
        print("|____________|/ ") 
    
    return

print("Hi there! What is your name?")
name = input()
print("Nice to meet you, " + name + ". Lets play a game of hangman.")
word = func_wordGet()
print("I am thinking of a word. It is " + str(len(word)) + " letters long." )
clue = len(word) * "_"
print(clue)

BadGuesses = 0
GoodGuesses = 0
Guesses = ""

while BadGuesses < 10:
    print("Take a guess at a letter....")
    guess = func_guess()
    let = []
    goodGuess = False

    for l in range(len(word)):
        if guess == word[l]:
            goodGuess = True
            GoodGuesses = GoodGuesses + 1
            let.append(l)

    if goodGuess != True:
        print("Tough luck, try again!")
        BadGuesses = BadGuesses + 1
    else:
        print("Good guess, you've got " + str(GoodGuesses) + " out of " + str(len(word)) + " letters correct.")
        for i in let:
            newclue = clue[:(i)] + guess + clue[(i+1):]
            clue = newclue

    
    print("You have guessed the letters " + Guesses)
    print("You have " + str(10 - BadGuesses) + " lives left.")
    print("")
    print("")
    print(clue)
    hang(BadGuesses)
    print("")
    if GoodGuesses == len(word):
        break

if BadGuesses == 10:
    print("The word was " + word)
    print("Tough luck. Try again next time")
else:
    print("Congratulations!")
    print("You won the game!")
# Out:
# Hi there! What is your name?
# Nice to meet you, Ed. Lets play a game of hangman.
# I am thinking of a word. It is 13 letters long.
# _____________
# Take a guess at a letter....
# Tough luck, try again!
# You have guessed the lettersa,
# You have 9 lives left.
#
#
# _____________
#
#
#
#
#
#
#   _____________
#  /            /|
# /____________/ /
# |____________|/
#
# Take a guess at a letter....
# Good guess, you've got 2 out of 13 letters correct.
# You have guessed the lettersa, e,
# You have 9 lives left.
#
#
# ________e__e_
#
#
#
#
#
#
#   _____________
#  /            /|
# /____________/ /
# |____________|/
#
# Take a guess at a letter....
# Tough luck, try again!
# You have guessed the lettersa, e, p,
# You have 8 lives left.
#
#
# ________e__e_
#
#
#     |
#     |
#     |
#     |
#   __|__________
#  /  |         /|
# /____________/ /
# |____________|/
#
# Take a guess at a letter....
# Good guess, you've got 5 out of 13 letters correct.
# You have guessed the lettersa, e, p, r,
# You have 8 lives left.
#
#
# ____r__re__er
#
#
#     |
#     |
#     |
#     |
#   __|__________
#  /  |         /|
# /____________/ /
# |____________|/
#
# Take a guess at a letter....
# Tough luck, try again!
# You have guessed the lettersa, e, p, r, i,
# You have 7 lives left.
#
#
# ____r__re__er
#
#     ________
#     |
#     |
#     |
#     |
#   __|__________
#  /  |         /|
# /____________/ /
# |____________|/
#
# Take a guess at a letter....
# Good guess, you've got 6 out of 13 letters correct.
# You have guessed the lettersa, e, p, r, i, o,
# You have 7 lives left.
#
#
# __o_r__re__er
#
#     ________
#     |
#     |
#     |
#     |
#   __|__________
#  /  |         /|
# /____________/ /
# |____________|/
#
# Take a guess at a letter....
# You have already that letter, try again.
# Tough luck, try again!
# You have guessed the lettersa, e, p, r, i, o, s,
# You have 6 lives left.
#
#
# __o_r__re__er
#
#     ________
#     |      |
#     |
#     |
#     |
#   __|__________
#  /  |         /|
# /____________/ /
# |____________|/
#
# Take a guess at a letter....
# Tough luck, try again!
# You have guessed the lettersa, e, p, r, i, o, s, c,
# You have 5 lives left.
#
#
# __o_r__re__er
#
#     ________
#     |      |
#     |      @
#     |
#     |
#   __|__________
#  /  |         /|
# /____________/ /
# |____________|/
#
# Take a guess at a letter....
# Tough luck, try again!
# You have guessed the lettersa, e, p, r, i, o, s, c, t,
# You have 4 lives left.
#
#
# __o_r__re__er
#
#     ________
#     |      |
#     |      @
#     |      |
#     |
#   __|__________
#  /  |         /|
# /____________/ /
# |____________|/
#
# Take a guess at a letter....
# Good guess, you've got 8 out of 13 letters correct.
# You have guessed the lettersa, e, p, r, i, o, s, c, t, d,
# You have 4 lives left.
#
#
# __o_r_dred_er
#
#     ________
#     |      |
#     |      @
#     |      |
#     |
#   __|__________
#  /  |         /|
# /____________/ /
# |____________|/
#
# Take a guess at a letter....
# Tough luck, try again!
# You have guessed the lettersa, e, p, r, i, o, s, c, t, d, n,
# You have 3 lives left.
#
#
# __o_r_dred_er
#
#     ________
#     |      |
#     |      @
#     |     /|
#     |
#   __|__________
#  /  |         /|
# /____________/ /
# |____________|/
#
# Take a guess at a letter....
# You have already that letter, try again.
# Good guess, you've got 9 out of 13 letters correct.
# You have guessed the lettersa, e, p, r, i, o, s, c, t, d, n, g,
# You have 3 lives left.
#
#
# __o_r_dredger
#
#     ________
#     |      |
#     |      @
#     |     /|
#     |
#   __|__________
#  /  |         /|
# /____________/ /
# |____________|/
#
# Take a guess at a letter....
# Good guess, you've got 10 out of 13 letters correct.
# You have guessed the lettersa, e, p, r, i, o, s, c, t, d, n, g, l,
# You have 3 lives left.
#
#
# _lo_r_dredger
#
#     ________
#     |      |
#     |      @
#     |     /|
#     |
#   __|__________
#  /  |         /|
# /____________/ /
# |____________|/
#
# Take a guess at a letter....
# You have already that letter, try again.
# You have already that letter, try again.
# You have already that letter, try again.
# Tough luck, try again!
# You have guessed the lettersa, e, p, r, i, o, s, c, t, d, n, g, l, q,
# You have 2 lives left.
#
#
# _lo_r_dredger
#
#     ________
#     |      |
#     |      @
#     |     /|\
#     |
#   __|__________
#  /  |         /|
# /____________/ /
# |____________|/
#
# Take a guess at a letter....
# Tough luck, try again!
# You have guessed the lettersa, e, p, r, i, o, s, c, t, d, n, g, l, q, w,
# You have 1 lives left.
#
#
# _lo_r_dredger
#
#     ________
#     |      |
#     |      @
#     |     /|\
#     |     /
#   __|__________
#  /  |         /|
# /____________/ /
# |____________|/
#
# Take a guess at a letter....
# You have already that letter, try again.
# You have already that letter, try again.
# You have already that letter, try again.
# Tough luck, try again!
# You have guessed the lettersa, e, p, r, i, o, s, c, t, d, n, g, l, q, w, y,
# You have 0 lives left.
#
#
# _lo_r_dredger
#
#     ________
#     |      |
#     |      @
#     |     /|\
#     |     / \
#   __|__________
#  /  |         /|
# /____________/ /
# |____________|/
#
# The word was flour-dredger
# Tough luck. Try again next time
